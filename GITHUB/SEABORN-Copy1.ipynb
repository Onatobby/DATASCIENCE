# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
tips= pd.read_csv('train.csv')

# %%
tips.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.distplot(tips['Fare'],kde=False,bins=30)

# %%
sns.distplot(tips['Fare'])

# %%
sns.jointplot(x='Fare',y='Survived',data=tips, kind='reg')

# %%
tips.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.jointplot(x='Fare',y='Age', data=tips, kind='kde')

# %%
#countplot is used for just one axis with double info example is sex: male and female

# %%
sns.countplot(x='Sex', data=tips)

# %%
sns.boxplot(x='Sex', y="Fare", data=tips,hue='Survived')

# %%
tips
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# sns.factorplot(x='Sex', y="Survived", data=tips, kind='violin')
# #factor plot is quite easy and faster because you can input any style you want

# %%
sns.factorplot(x='Sex', y="Survived", data=tips, kind='violin')

# %%
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7dfb648b56f5> in <module>()
# ----> 1 cf.go_offline()
#
# NameError: name 'cf' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel

# %%
sns.Implot(x='Fare', y="Survived", data =tips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-bb731dffcc3c> in <module>()
# ----> 1 sns.Implot(x='Fare', y="Survived", data =tips)
#
# AttributeError: 'module' object has no attribute 'Implot'

# %%
tips.drop('Ticket')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-da5ab9fa8760> in <module>()
# ----> 1 tips.drop('Ticket')
#       2
#
# D:\WinPython-32bit-3.4.4.6Qt5\python-3.4.4\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# D:\WinPython-32bit-3.4.4.6Qt5\python-3.4.4\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
# ...

# %%
sns.isnull(tips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-78aa7730d530> in <module>()
# ----> 1 sns.isnull(tips)
#
# AttributeError: 'module' object has no attribute 'isnull'
